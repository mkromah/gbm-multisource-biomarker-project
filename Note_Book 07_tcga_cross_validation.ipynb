# %% [markdown]
# <a href="https://colab.research.google.com/github/mkromah/gbm-multisource-biomarker-project/blob/main/Note_Book%2007_tcga_cross_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# Mount Google Drive
# ============================================================

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# Project paths and imports
# ============================================================

import os
import numpy as np
import pandas as pd

PROJECT_NAME = "Glioma_ML_Biomarker_Project"
BASE_DIR = f"/content/drive/MyDrive/{PROJECT_NAME}"

DATA_DIR = f"{BASE_DIR}/data"
RAW_DIR = f"{DATA_DIR}/raw"

RESULTS_DIR = f"{BASE_DIR}/results"
FIGURES_DIR = f"{RESULTS_DIR}/figures"
TABLES_DIR = f"{RESULTS_DIR}/tables"

XENA_DIR = f"{RAW_DIR}/XENA"

print("Project root loaded:")
print(BASE_DIR)
# Out:
# Project root loaded:
# /content/drive/MyDrive/Glioma_ML_Biomarker_Project

# %%
# ============================================================
# Project paths and imports
# ============================================================

import os
import numpy as np
import pandas as pd

PROJECT_NAME = "Glioma_ML_Biomarker_Project"
BASE_DIR = f"/content/drive/MyDrive/{PROJECT_NAME}"

DATA_DIR = f"{BASE_DIR}/data"
RAW_DIR = f"{DATA_DIR}/raw"

RESULTS_DIR = f"{BASE_DIR}/results"
FIGURES_DIR = f"{RESULTS_DIR}/figures"
TABLES_DIR = f"{RESULTS_DIR}/tables"

XENA_DIR = f"{RAW_DIR}/XENA"

print("Project root loaded:")
print(BASE_DIR)
# Out:
# Project root loaded:
# /content/drive/MyDrive/Glioma_ML_Biomarker_Project

# %%
# ============================================================
# Step 2: Load final biomarker panel
# ============================================================

final_biomarker_path = f"{RESULTS_DIR}/final_cross_cohort_biomarkers.csv"

final_biomarkers = pd.read_csv(final_biomarker_path)

print("Final biomarker panel loaded.")
print("Shape:", final_biomarkers.shape)

print("\nGenes:")
print(final_biomarkers["gene"].tolist())
# Out:
# Final biomarker panel loaded.
# Shape: (21, 2)
#
# Genes:
# ['MMP9', 'LINC00152', 'ESM1', 'CLIC1', 'SERPINH1', 'AGAP2-AS1', 'KCNB1', 'ANXA2', 'LOX', 'CCDC109B', 'EMP3', 'PLEK2', 'SH2D4A', 'TUBA1C', 'FN1', 'TNFRSF12A', 'RAB34', 'CA9', 'TAGLN2', 'GDF15', 'SPAG4']

# %%
# ============================================================
# Step 3: Load TCGA phenotype metadata
# ============================================================

pheno_path = f"{XENA_DIR}/TcgaTargetGTEX_phenotype.txt.gz"

pheno = pd.read_csv(
    pheno_path,
    sep="\t",
    compression="gzip",
    encoding="latin1"
)

print("Phenotype table loaded.")
print("Shape:", pheno.shape)

pheno.head()
# Out:
# Phenotype table loaded.
# Shape: (19131, 7)
#             sample detailed_category primary disease or tissue _primary_site  \
# 0  TCGA-V4-A9EE-01    Uveal Melanoma            Uveal Melanoma           Eye
# 1  TCGA-VD-AA8N-01    Uveal Melanoma            Uveal Melanoma           Eye
# 2  TCGA-V4-A9EI-01    Uveal Melanoma            Uveal Melanoma           Eye
# 3  TCGA-VD-AA8O-01    Uveal Melanoma            Uveal Melanoma           Eye
# 4  TCGA-WC-A888-01    Uveal Melanoma            Uveal Melanoma           Eye
#
#     _sample_type _gender _study
# 0  Primary Tumor    Male   TCGA
# 1  Primary Tumor    Male   TCGA
# 2  Primary Tumor    Male   TCGA
# 3  Primary Tumor    Male   TCGA
# 4  Primary Tumor    Male   TCGA

# %%
# ============================================================
# Step 4: Extract TCGA glioma samples
# ============================================================

glioma_categories = ["Brain Lower Grade Glioma", "Glioblastoma Multiforme"]

tcga_glioma_meta = pheno[
    pheno["detailed_category"].isin(glioma_categories)
].copy()

tcga_glioma_meta = tcga_glioma_meta[
    tcga_glioma_meta["_sample_type"] == "Primary Tumor"
].copy()

print("TCGA glioma samples extracted.")
print("Shape:", tcga_glioma_meta.shape)

print("\nLabel distribution:")
print(tcga_glioma_meta["detailed_category"].value_counts())
# Out:
# TCGA glioma samples extracted.
# Shape: (662, 7)
#
# Label distribution:
# detailed_category
# Brain Lower Grade Glioma    509
# Glioblastoma Multiforme     153
# Name: count, dtype: int64

# %%
 # ============================================================
# Recreate project paths
# ============================================================

PROJECT_NAME = "Glioma_ML_Biomarker_Project"
BASE_DIR = f"/content/drive/MyDrive/{PROJECT_NAME}"

DATA_DIR = f"{BASE_DIR}/data"
RAW_DIR = f"{DATA_DIR}/raw"

RESULTS_DIR = f"{BASE_DIR}/results"
FIGURES_DIR = f"{RESULTS_DIR}/figures"
TABLES_DIR = f"{RESULTS_DIR}/tables"

XENA_DIR = f"{RAW_DIR}/XENA"

print("BASE_DIR:", BASE_DIR)
print("RAW_DIR:", RAW_DIR)
print("XENA_DIR:", XENA_DIR)
# Out:
# BASE_DIR: /content/drive/MyDrive/Glioma_ML_Biomarker_Project
# RAW_DIR: /content/drive/MyDrive/Glioma_ML_Biomarker_Project/data/raw
# XENA_DIR: /content/drive/MyDrive/Glioma_ML_Biomarker_Project/data/raw/XENA

# %%
# ============================================================
# Recovery setup: imports + project paths
# ============================================================

import os
import numpy as np
import pandas as pd

PROJECT_NAME = "Glioma_ML_Biomarker_Project"
BASE_DIR = f"/content/drive/MyDrive/{PROJECT_NAME}"

DATA_DIR = f"{BASE_DIR}/data"
RAW_DIR = f"{DATA_DIR}/raw"

RESULTS_DIR = f"{BASE_DIR}/results"
FIGURES_DIR = f"{RESULTS_DIR}/figures"
TABLES_DIR = f"{RESULTS_DIR}/tables"

XENA_DIR = f"{RAW_DIR}/XENA"

print("BASE_DIR:", BASE_DIR)
print("XENA_DIR:", XENA_DIR)
# Out:
# BASE_DIR: /content/drive/MyDrive/Glioma_ML_Biomarker_Project
# XENA_DIR: /content/drive/MyDrive/Glioma_ML_Biomarker_Project/data/raw/XENA

# %%
# ============================================================
# Step 5: Load TCGA expression matrix
# ============================================================

expr_path = f"{XENA_DIR}/TcgaTargetGtex_rsem_gene_tpm.gz"

expr = pd.read_csv(
    expr_path,
    sep="\t",
    compression="gzip"
)

print("Expression matrix loaded.")
print("Shape:", expr.shape)

expr.head()
# Out:
# Expression matrix loaded.
# Shape: (60498, 19132)
#                sample  GTEX-S4Q7-0003-SM-3NM8M  TCGA-19-1787-01  \
# 0   ENSG00000242268.2                  -3.4580          -9.9658
# 1   ENSG00000259041.1                  -9.9658          -9.9658
# 2   ENSG00000270112.3                  -3.6259          -3.8160
# 3  ENSG00000167578.16                   4.5988           5.2998
# 4   ENSG00000278814.1                  -9.9658          -9.9658
#
#    TCGA-S9-A7J2-01  GTEX-QV31-1626-SM-2S1QC  TCGA-G3-A3CH-11  TCGA-B5-A5OE-01  \
# 0           0.2998                  -9.9658          -9.9658          -9.9658
# 1          -9.9658                  -9.9658          -9.9658          -9.9658
# 2          -3.0469                  -2.1779          -9.9658          -9.9658
# 3           4.8881                   4.6294           3.5572           5.0858
# 4          -9.9658                  -9.9658          -9.9658          -9.9658
#
# ...

# %%
# ============================================================
# Step 6: Load gene annotation map
# ============================================================

gene_map_path = f"{XENA_DIR}/probeMap_gencode.v23.annotation.gene.probemap"

gene_map = pd.read_csv(
    gene_map_path,
    sep="\t"
)

print("Gene annotation map loaded.")
print("Shape:", gene_map.shape)

gene_map.head()
# Out:
# Gene annotation map loaded.
# Shape: (60498, 6)
#                   id          gene chrom  chromStart  chromEnd strand
# 0  ENSG00000223972.5       DDX11L1  chr1       11869     14409      +
# 1  ENSG00000227232.5        WASH7P  chr1       14404     29570      -
# 2  ENSG00000278267.1     MIR6859-1  chr1       17369     17436      -
# 3  ENSG00000243485.3  RP11-34P13.3  chr1       29554     31109      +
# 4  ENSG00000274890.1     MIR1302-2  chr1       30366     30503      +

# %%
# ============================================================
# Step 7: Map Ensembl IDs to gene symbols
# ============================================================

expr = expr.copy()
expr["ensembl_id"] = expr["sample"].astype(str).str.split(".").str[0]

gene_map = gene_map.copy()
gene_map["ensembl_id"] = gene_map["id"].astype(str).str.split(".").str[0]

expr_annot = expr.merge(
    gene_map[["ensembl_id", "gene"]],
    on="ensembl_id",
    how="left"
)

print("Expression matrix mapped to gene symbols.")
print("Shape:", expr_annot.shape)

expr_annot[["sample", "ensembl_id", "gene"]].head()
# Out:
# Expression matrix mapped to gene symbols.
# Shape: (60498, 19134)
#                sample       ensembl_id           gene
# 0   ENSG00000242268.2  ENSG00000242268  RP11-368I23.2
# 1   ENSG00000259041.1  ENSG00000259041   RP11-167B3.1
# 2   ENSG00000270112.3  ENSG00000270112  RP11-742D12.2
# 3  ENSG00000167578.16  ENSG00000167578          RAB4B
# 4   ENSG00000278814.1  ENSG00000278814     AC104071.1

# %%
# ============================================================
# Step 8: Keep only final biomarker genes
# ============================================================

biomarker_genes = final_biomarkers["gene"].dropna().unique().tolist()

expr_biomarkers = expr_annot[
    expr_annot["gene"].isin(biomarker_genes)
].copy()

print("Biomarker expression matrix extracted.")
print("Shape:", expr_biomarkers.shape)

print("\nExtracted genes:")
print(sorted(expr_biomarkers["gene"].dropna().unique().tolist()))
# Out:
# Biomarker expression matrix extracted.
# Shape: (21, 19134)
#
# Extracted genes:
# ['AGAP2-AS1', 'ANXA2', 'CA9', 'CCDC109B', 'CLIC1', 'EMP3', 'ESM1', 'FN1', 'GDF15', 'KCNB1', 'LINC00152', 'LOX', 'MMP9', 'PLEK2', 'RAB34', 'SERPINH1', 'SH2D4A', 'SPAG4', 'TAGLN2', 'TNFRSF12A', 'TUBA1C']

# %%
# ============================================================
# Step 9: Build TCGA biomarker matrix
# ============================================================

# Set gene as index
expr_biomarkers = expr_biomarkers.set_index("gene")

# Drop annotation columns
expr_biomarkers = expr_biomarkers.drop(columns=["sample", "ensembl_id"], errors="ignore")

# Transpose so samples become rows
tcga_matrix = expr_biomarkers.T

print("TCGA biomarker matrix created.")
print("Shape:", tcga_matrix.shape)

tcga_matrix.head()
# Out:
# TCGA biomarker matrix created.
# Shape: (19131, 21)
# gene                       ESM1  TUBA1C   SPAG4   KCNB1   PLEK2      FN1  \
# GTEX-S4Q7-0003-SM-3NM8M -5.5735  7.0023  5.4290 -6.5064 -4.2934   2.0147
# TCGA-19-1787-01          1.0779  8.8210  0.8488  2.2144  1.4335   8.1679
# TCGA-S9-A7J2-01         -1.2828  4.3807 -0.9971  3.1011 -2.1140   6.0943
# GTEX-QV31-1626-SM-2S1QC -2.7274  7.1385  1.2516  0.6880 -0.0725  12.4655
# TCGA-G3-A3CH-11         -5.0116  4.6387  1.4335 -1.9379  1.5806  10.1893
#
# gene                      ANXA2     CA9  AGAP2-AS1   CLIC1  ...  CCDC109B  \
# GTEX-S4Q7-0003-SM-3NM8M  5.3024 -2.9324    -0.6873  8.8275  ...    4.6497
# TCGA-19-1787-01          9.3479  2.2299     3.4061  8.1538  ...    5.2634
# TCGA-S9-A7J2-01          3.5706 -0.1504     0.4657  4.2404  ...    1.0847
# GTEX-QV31-1626-SM-2S1QC  9.7622  0.9419     2.7029  7.9634  ...    2.7721
# TCGA-G3-A3CH-11          5.4686  0.6517    -0.3752  5.6846  ...    0.4016
#
# ...

# %%
# ============================================================
# Step 10: Keep only TCGA glioma samples
# ============================================================

glioma_sample_ids = tcga_glioma_meta["sample"].tolist()

tcga_glioma_matrix = tcga_matrix.loc[tcga_matrix.index.intersection(glioma_sample_ids)].copy()

print("TCGA glioma biomarker matrix created.")
print("Shape:", tcga_glioma_matrix.shape)

tcga_glioma_matrix.head()
# Out:
# TCGA glioma biomarker matrix created.
# Shape: (662, 21)
# gene               ESM1  TUBA1C   SPAG4   KCNB1   PLEK2     FN1   ANXA2  \
# TCGA-19-1787-01  1.0779  8.8210  0.8488  2.2144  1.4335  8.1679  9.3479
# TCGA-S9-A7J2-01 -1.2828  4.3807 -0.9971  3.1011 -2.1140  6.0943  3.5706
# TCGA-E1-A7YI-01 -3.3076  4.3938  0.5370  2.3106 -0.9686  7.4119  6.5097
# TCGA-06-5412-01  3.3966  8.6443  3.0020 -1.3548  2.9071  9.7850  9.1379
# TCGA-DU-7302-01 -3.8160  3.6054 -1.8314  4.4588 -0.9686  5.5766  4.6047
#
# gene                CA9  AGAP2-AS1   CLIC1  ...  CCDC109B     LOX  SERPINH1  \
# TCGA-19-1787-01  2.2299     3.4061  8.1538  ...    5.2634  3.0234    6.6521
# TCGA-S9-A7J2-01 -0.1504     0.4657  4.2404  ...    1.0847 -1.3921    4.5922
# TCGA-E1-A7YI-01 -1.3548     0.4761  7.2855  ...    2.1147  0.5170    5.4142
# TCGA-06-5412-01  4.7682     2.9469  9.0624  ...    5.0396  5.5528    7.0677
# TCGA-DU-7302-01 -1.0559    -0.4719  4.3278  ...    1.8840 -0.8599    3.3633
#
# ...

# %%
# ============================================================
# Step 11: Create labels and split X / y
# ============================================================

label_map = tcga_glioma_meta.set_index("sample")["detailed_category"].map({
    "Brain Lower Grade Glioma": 0,
    "Glioblastoma Multiforme": 1
})

y_tcga = tcga_glioma_matrix.index.to_series().map(label_map)
X_tcga = tcga_glioma_matrix.copy()

print("Feature matrix shape:", X_tcga.shape)
print("Label vector shape:", y_tcga.shape)

print("\nLabel distribution:")
print(y_tcga.value_counts())
# Out:
# Feature matrix shape: (662, 21)
# Label vector shape: (662,)
#
# Label distribution:
# 0    509
# 1    153
# Name: count, dtype: int64

# %%
# ============================================================
# Step 12: Random Forest cross-validation
# ============================================================

from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    n_jobs=-1
)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

scoring = {
    "accuracy": "accuracy",
    "roc_auc": "roc_auc"
}

cv_results_rf = cross_validate(
    rf_model,
    X_tcga,
    y_tcga,
    cv=cv,
    scoring=scoring,
    return_train_score=False
)

print("Random Forest 5-Fold Cross-Validation")
print("--------------------------------------")

print("Mean Accuracy :", round(cv_results_rf["test_accuracy"].mean(),4))
print("Std Accuracy  :", round(cv_results_rf["test_accuracy"].std(),4))

print("Mean ROC-AUC  :", round(cv_results_rf["test_roc_auc"].mean(),4))
print("Std ROC-AUC   :", round(cv_results_rf["test_roc_auc"].std(),4))
# Out:
# Random Forest 5-Fold Cross-Validation
# --------------------------------------
# Mean Accuracy : 0.935
# Std Accuracy  : 0.0207
# Mean ROC-AUC  : 0.9737
# Std ROC-AUC   : 0.0093

# %%
# ============================================================
# Step 13: Cross-validation for Logistic Regression & XGBoost
# ============================================================

from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

# Logistic Regression
log_model = LogisticRegression(max_iter=5000)

cv_results_log = cross_validate(
    log_model,
    X_tcga,
    y_tcga,
    cv=cv,
    scoring=scoring
)

# XGBoost
xgb_model = XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric="logloss"
)

cv_results_xgb = cross_validate(
    xgb_model,
    X_tcga,
    y_tcga,
    cv=cv,
    scoring=scoring
)

print("Logistic Regression CV AUC:", round(cv_results_log["test_roc_auc"].mean(),4))
print("XGBoost CV AUC:", round(cv_results_xgb["test_roc_auc"].mean(),4))
# Out:
# Logistic Regression CV AUC: 0.9706
# XGBoost CV AUC: 0.9699

# %%
# ============================================================
# Step 14: Cross-validation comparison table
# ============================================================

cv_table = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest", "XGBoost"],
    "Mean Accuracy": [
        cv_results_log["test_accuracy"].mean(),
        cv_results_rf["test_accuracy"].mean(),
        cv_results_xgb["test_accuracy"].mean()
    ],
    "Mean ROC_AUC": [
        cv_results_log["test_roc_auc"].mean(),
        cv_results_rf["test_roc_auc"].mean(),
        cv_results_xgb["test_roc_auc"].mean()
    ]
})

cv_table = cv_table.sort_values(by="Mean ROC_AUC", ascending=False)

print("Cross-Validation Model Performance")
display(cv_table)
# Out:
# Cross-Validation Model Performance
#                  Model  Mean Accuracy  Mean ROC_AUC
# 1        Random Forest       0.935019      0.973683
# 0  Logistic Regression       0.930497      0.970607
# 2              XGBoost       0.924459      0.969918

# %%
cv_table.to_csv(
    f"{TABLES_DIR}/cross_validation_results.csv",
    index=False
)

print("Cross-validation results saved.")
# Out:
# Cross-validation results saved.
